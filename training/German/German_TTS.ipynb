# %%
# %cd espnet
# Out:
# /home/ec2-user/SageMaker/espnet

# %%
# %cd /home/ec2-user/SageMaker/espnet/tools
# Out:
# /home/ec2-user/SageMaker/espnet/tools

# %%
# %%capture 
# !./setup_anaconda.sh "/home/ec2-user/anaconda3" espnet 3.8.12
#!./setup_venv.sh $(command -v python3)

# %%
# !conda install -y -c conda-forge libsndfile
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/t2s
#
#   added / updated specs:
#     - libsndfile
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libflac-1.3.4              |       h27087fc_0         474 KB  conda-forge
#     libsndfile-1.0.31          |       h9c3ff4c_1         602 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   libflac            conda-forge/linux-64::libflac-1.3.4-h27087fc_0
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libsndfile         conda-forge/linux-64::libsndfile-1.0.31-h9c3ff4c_1
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#
#
#
# Downloading and Extracting Packages
# libflac-1.3.4        | 474 KB    | ##################################### | 100%
# libsndfile-1.0.31    | 602 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c conda-forge librosa
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/t2s
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.3.0                  |       h27087fc_1         2.6 MB  conda-forge
#     audioread-2.1.9            |   py38h578d9bd_3          33 KB  conda-forge
#     brotli-1.0.9               |       h166bdaf_7          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_7          19 KB  conda-forge
#     ffmpeg-5.0.1               |       h594f047_0        10.1 MB  conda-forge
#     fonttools-4.32.0           |   py38h0a891b7_0         1.6 MB  conda-forge
#     icu-70.1                   |       h27087fc_0        13.5 MB  conda-forge
#     kiwisolver-1.4.2           |   py38h43d8883_1          75 KB  conda-forge
#     libblas-3.9.0              |14_linux64_openblas          12 KB  conda-forge
#     libbrotlicommon-1.0.9      |       h166bdaf_7          65 KB  conda-forge
#     libbrotlidec-1.0.9         |       h166bdaf_7          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       h166bdaf_7         287 KB  conda-forge
#     libcblas-3.9.0             |14_linux64_openblas          12 KB  conda-forge
#     libdrm-2.4.109             |       h7f98852_0         284 KB  conda-forge
#     libgfortran-ng-11.2.0      |      h69a702a_15          23 KB  conda-forge
#     libgfortran5-11.2.0        |      h5c6108e_15         1.7 MB  conda-forge
#     liblapack-3.9.0            |14_linux64_openblas          12 KB  conda-forge
#     libllvm11-11.1.0           |       hf817b99_3        29.1 MB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     libpciaccess-0.16          |       h516909a_0          37 KB  conda-forge
#     librosa-0.9.1              |     pyhd8ed1ab_0         154 KB  conda-forge
#     libva-2.14.0               |       h7f98852_0         183 KB  conda-forge
#     libvpx-1.11.0              |       h9c3ff4c_3         1.1 MB  conda-forge
#     libxml2-2.9.13             |       h22db469_0         773 KB  conda-forge
#     llvmlite-0.38.0            |   py38h38d86a4_1         2.3 MB  conda-forge
#     matplotlib-base-3.5.1      |   py38hf4fb855_0         7.4 MB  conda-forge
#     numba-0.55.1               |   py38h4bf6c61_0         3.8 MB  conda-forge
#     numpy-1.21.6               |   py38h1d589f8_0         6.2 MB  conda-forge
#     pillow-9.1.0               |   py38h0ee0e06_2        44.7 MB  conda-forge
#     pooch-1.6.0                |     pyhd8ed1ab_0          44 KB  conda-forge
#     pysoundfile-0.10.3.post1   |     pyhd3deb0d_0          23 KB  conda-forge
#     resampy-0.2.2              |             py_0         332 KB  conda-forge
#     scikit-learn-1.0.2         |   py38h1561384_0         8.0 MB  conda-forge
#     scipy-1.8.0                |   py38h56a6a73_1        23.6 MB  conda-forge
#     svt-av1-0.9.1              |       h27087fc_0         3.3 MB  conda-forge
#     unicodedata2-14.0.0        |   py38h0a891b7_1         498 KB  conda-forge
#     x264-1!161.3030            |       h7f98852_1         2.5 MB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       177.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.3.0-h27087fc_1
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   audioread          conda-forge/linux-64::audioread-2.1.9-py38h578d9bd_3
#   brotli             conda-forge/linux-64::brotli-1.0.9-h166bdaf_7
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h166bdaf_7
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py38h0a891b7_1004
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   certifi            conda-forge/linux-64::certifi-2021.10.8-py38h578d9bd_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py38hd667e15_1
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.0.12-pyhd8ed1ab_0
#   cryptography       conda-forge/linux-64::cryptography-36.0.2-py38h2b5fc30_1
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-5.0.1-h594f047_0
#   fonttools          conda-forge/linux-64::fonttools-4.32.0-py38h0a891b7_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   icu                conda-forge/linux-64::icu-70.1-h27087fc_0
#   idna               conda-forge/noarch::idna-3.3-pyhd8ed1ab_0
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   joblib             conda-forge/noarch::joblib-1.1.0-pyhd8ed1ab_0
#   jpeg               conda-forge/linux-64::jpeg-9e-h7f98852_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.2-py38h43d8883_1
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   lerc               conda-forge/linux-64::lerc-3.0-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-14_linux64_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.0.9-h166bdaf_7
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.0.9-h166bdaf_7
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.0.9-h166bdaf_7
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-14_linux64_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.10-h7f98852_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.109-h7f98852_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-11.2.0-h69a702a_15
#   libgfortran5       conda-forge/linux-64::libgfortran5-11.2.0-h5c6108e_15
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-14_linux64_openblas
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-hf817b99_3
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.16-h516909a_0
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   librosa            conda-forge/noarch::librosa-0.9.1-pyhd8ed1ab_0
#   libtiff            conda-forge/linux-64::libtiff-4.3.0-h542a066_3
#   libva              conda-forge/linux-64::libva-2.14.0-h7f98852_0
#   libvpx             conda-forge/linux-64::libvpx-1.11.0-h9c3ff4c_3
#   libwebp            conda-forge/linux-64::libwebp-1.2.2-h3452ae3_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.2-h7f98852_1
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   libxml2            conda-forge/linux-64::libxml2-2.9.13-h22db469_0
#   llvmlite           conda-forge/linux-64::llvmlite-0.38.0-py38h38d86a4_1
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.5.1-py38hf4fb855_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   numba              conda-forge/linux-64::numba-0.55.1-py38h4bf6c61_0
#   numpy              conda-forge/linux-64::numpy-1.21.6-py38h1d589f8_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   pillow             conda-forge/linux-64::pillow-9.1.0-py38h0ee0e06_2
#   pooch              conda-forge/noarch::pooch-1.6.0-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pycparser          conda-forge/noarch::pycparser-2.21-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-22.0.0-pyhd8ed1ab_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py38h578d9bd_5
#   pysoundfile        conda-forge/noarch::pysoundfile-0.10.3.post1-pyhd3deb0d_0
#   requests           conda-forge/noarch::requests-2.27.1-pyhd8ed1ab_0
#   resampy            conda-forge/noarch::resampy-0.2.2-py_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.0.2-py38h1561384_0
#   scipy              conda-forge/linux-64::scipy-1.8.0-py38h56a6a73_1
#   svt-av1            conda-forge/linux-64::svt-av1-0.9.1-h27087fc_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.1.0-pyh8a188c0_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-14.0.0-py38h0a891b7_1
#   urllib3            conda-forge/noarch::urllib3-1.26.9-pyhd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!161.3030-h7f98852_1
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.5.2-ha95c52a_0
#
#
#
# Downloading and Extracting Packages
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# icu-70.1             | 13.5 MB   | ##################################### | 100%
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
# libva-2.14.0         | 183 KB    | ##################################### | 100%
# matplotlib-base-3.5. | 7.4 MB    | ##################################### | 100%
# libvpx-1.11.0        | 1.1 MB    | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# x264-1!161.3030      | 2.5 MB    | ##################################### | 100%
# libllvm11-11.1.0     | 29.1 MB   | ##################################### | 100%
# libbrotlienc-1.0.9   | 287 KB    | ##################################### | 100%
# libopenblas-0.3.20   | 10.1 MB   | ##################################### | 100%
# libxml2-2.9.13       | 773 KB    | ##################################### | 100%
# ffmpeg-5.0.1         | 10.1 MB   | ##################################### | 100%
# kiwisolver-1.4.2     | 75 KB     | ##################################### | 100%
# pillow-9.1.0         | 44.7 MB   | ##################################### | 100%
# aom-3.3.0            | 2.6 MB    | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# libpciaccess-0.16    | 37 KB     | ##################################### | 100%
# libgfortran5-11.2.0  | 1.7 MB    | ##################################### | 100%
# unicodedata2-14.0.0  | 498 KB    | ##################################### | 100%
# brotli-bin-1.0.9     | 19 KB     | ##################################### | 100%
# scipy-1.8.0          | 23.6 MB   | ##################################### | 100%
# audioread-2.1.9      | 33 KB     | ##################################### | 100%
# libgfortran-ng-11.2. | 23 KB     | ##################################### | 100%
# numpy-1.21.6         | 6.2 MB    | ##################################### | 100%
# libbrotlicommon-1.0. | 65 KB     | ##################################### | 100%
# pooch-1.6.0          | 44 KB     | ##################################### | 100%
# llvmlite-0.38.0      | 2.3 MB    | ##################################### | 100%
# resampy-0.2.2        | 332 KB    | ##################################### | 100%
# svt-av1-0.9.1        | 3.3 MB    | ##################################### | 100%
# librosa-0.9.1        | 154 KB    | ##################################### | 100%
# pysoundfile-0.10.3.p | 23 KB     | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# libdrm-2.4.109       | 284 KB    | ##################################### | 100%
# scikit-learn-1.0.2   | 8.0 MB    | ##################################### | 100%
# numba-0.55.1         | 3.8 MB    | ##################################### | 100%
# fonttools-4.32.0     | 1.6 MB    | ##################################### | 100%
# x265-3.5             | 3.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install SoundFile
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: SoundFile in /home/ec2-user/anaconda3/envs/t2s/lib/python3.8/site-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /home/ec2-user/anaconda3/envs/t2s/lib/python3.8/site-packages (from SoundFile) (1.15.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/t2s/lib/python3.8/site-packages (from cffi>=1.0->SoundFile) (2.21)

# %%
# !make TH_VERSION=1.8.0 CUDA_VERSION=10.2
# Out:
# Perform on CPU mode: CPU_ONLY=0
# PYTHON=/home/ec2-user/anaconda3/envs/espnet/bin/python3
# PYTHON_VERSION=Python 3.8.12
# USE_CONDA=1
# TH_VERSION=1.8.0
# # NOTE(kan-bayashi): Temporary fixed numpy version
# . ./activate_python.sh && conda install -y "numpy<=1.21.3"
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/espnet
#
#   added / updated specs:
#     - numpy[version='<=1.21.3']
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-1.20.3               |   py38h8246c76_2         5.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   libblas            conda-forge/linux-64::libblas-3.9.0-14_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-14_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-11.2.0-h69a702a_15
#   libgfortran5       conda-forge/linux-64::libgfortran5-11.2.0-h5c6108e_15
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-14_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   numpy              conda-forge/linux-64::numpy-1.20.3-py38h8246c76_2
#
#
#
# Downloading and Extracting Packages
# numpy-1.20.3         | 5.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# . ./activate_python.sh && ./installers/install_torch.sh "true" "1.8.0" "10.2"
# 2022-04-17T16:15:22 (install_torch.sh:119:main) [INFO] python_version=3.8.12
# 2022-04-17T16:15:22 (install_torch.sh:120:main) [INFO] torch_version=1.8.0
# 2022-04-17T16:15:22 (install_torch.sh:121:main) [INFO] cuda_version=10.2
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# <stdin>:2: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# 2022-04-17T16:15:24 (install_torch.sh:67:install_torch) conda install -y pytorch=1.8.0 torchaudio=0.8.0 cudatoolkit=10.2 -c pytorch
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/espnet
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch=1.8.0
#     - torchaudio=0.8.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     cudatoolkit-10.2.89        |      h8f6ccaa_10       449.9 MB  conda-forge
#     intel-openmp-2022.0.1      |    h06a4308_3633         4.2 MB
#     libblas-3.9.0              |   14_linux64_mkl          13 KB  conda-forge
#     libcblas-3.9.0             |   14_linux64_mkl          12 KB  conda-forge
#     liblapack-3.9.0            |   14_linux64_mkl          12 KB  conda-forge
#     mkl-2022.0.1               |     h06a4308_117       127.7 MB
#     ninja-1.10.2               |       h4bd325d_1         2.4 MB  conda-forge
#     pytorch-1.8.0              |py3.8_cuda10.2_cudnn7.6.5_0       672.7 MB  pytorch
#     torchaudio-0.8.0           |             py38         4.4 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        1.23 GB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-10.2.89-h8f6ccaa_10
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2022.0.1-h06a4308_3633
#   libuv              conda-forge/linux-64::libuv-1.43.0-h7f98852_0
#   mkl                pkgs/main/linux-64::mkl-2022.0.1-h06a4308_117
#   ninja              conda-forge/linux-64::ninja-1.10.2-h4bd325d_1
#   pytorch            pytorch/linux-64::pytorch-1.8.0-py3.8_cuda10.2_cudnn7.6.5_0
#   torchaudio         pytorch/linux-64::torchaudio-0.8.0-py38
#   typing_extensions  conda-forge/noarch::typing_extensions-4.1.1-pyha770c72_0
#
# The following packages will be DOWNGRADED:
#
#   libblas                         3.9.0-14_linux64_openblas --> 3.9.0-14_linux64_mkl
#   libcblas                        3.9.0-14_linux64_openblas --> 3.9.0-14_linux64_mkl
#   liblapack                       3.9.0-14_linux64_openblas --> 3.9.0-14_linux64_mkl
#
#
#
# Downloading and Extracting Packages
# cudatoolkit-10.2.89  | 449.9 MB  | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# torchaudio-0.8.0     | 4.4 MB    | ##################################### | 100%
# mkl-2022.0.1         | 127.7 MB  | ##################################### | 100%
# pytorch-1.8.0        | 672.7 MB  | ##################################### | 100%
# intel-openmp-2022.0. | 4.2 MB    | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# libblas-3.9.0        | 13 KB     | ##################################### | 100%
# ninja-1.10.2         | 2.4 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: \ By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# touch pytorch.done
# . ./activate_python.sh && { command -v bc || conda install -y bc -c conda-forge; }
# /usr/bin/bc
# touch bc.done
# . ./activate_python.sh && { command -v cmake || conda install -y cmake; }
# /usr/local/bin/cmake
# touch cmake.done
# . ./activate_python.sh && { command -v flac || conda install -y libflac -c conda-forge; }
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/espnet
#
#   added / updated specs:
#     - libflac
#
#
# The following NEW packages will be INSTALLED:
#
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   libflac            conda-forge/linux-64::libflac-1.3.4-h27087fc_0
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# touch flac.done
# . ./activate_python.sh && { command -v ffmpeg || conda install -y ffmpeg -c conda-forge; }
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/espnet
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.3.0-h27087fc_1
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   ffmpeg             conda-forge/linux-64::ffmpeg-5.0.1-h594f047_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   icu                conda-forge/linux-64::icu-70.1-h27087fc_0
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   libdrm             conda-forge/linux-64::libdrm-2.4.109-h7f98852_0
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.16-h516909a_0
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libva              conda-forge/linux-64::libva-2.14.0-h7f98852_0
#   libvpx             conda-forge/linux-64::libvpx-1.11.0-h9c3ff4c_3
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   libxml2            conda-forge/linux-64::libxml2-2.9.13-h22db469_0
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   svt-av1            conda-forge/linux-64::svt-av1-0.9.1-h27087fc_0
#   x264               conda-forge/linux-64::x264-1!161.3030-h7f98852_1
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# touch ffmpeg.done
# . ./activate_python.sh && { command -v sox || conda install -y sox -c conda-forge; }
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/espnet
#
#   added / updated specs:
#     - sox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mad-0.15.1b                |       h9c3ff4c_1         113 KB  conda-forge
#     sox-14.4.2                 |    hceab884_1015         765 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         878 KB
#
# The following NEW packages will be INSTALLED:
#
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libsndfile         conda-forge/linux-64::libsndfile-1.0.31-h9c3ff4c_1
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   mad                conda-forge/linux-64::mad-0.15.1b-h9c3ff4c_1
#   sox                conda-forge/linux-64::sox-14.4.2-hceab884_1015
#
#
#
# Downloading and Extracting Packages
# mad-0.15.1b          | 113 KB    | ##################################### | 100%
# sox-14.4.2           | 765 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# touch sox.done
# . ./activate_python.sh && { python3 -c "from ctypes.util import find_library as F; assert F('sndfile') is not None" || conda install -y libsndfile=1.0.28 -c conda-forge; }
# touch sndfile.done
# touch conda_packages.done
# . ./activate_python.sh && python3 -m pip install -e "..[train, recipe]"  # Install editable mode by default
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Obtaining file:///home/ec2-user/SageMaker/espnet
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=38.5.1 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from espnet==202204) (62.1.0)
# Collecting configargparse>=1.2.1
#   Downloading ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Collecting typeguard>=2.7.0
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting humanfriendly
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 16.7 MB/s eta 0:00:00
# Collecting scipy>=1.4.1
#   Downloading scipy-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 11.8 MB/s eta 0:00:0000:0100:01
# Collecting filelock
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Collecting librosa>=0.8.0
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 KB 50.2 MB/s eta 0:00:00
# Collecting jamo==0.4.1
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Collecting PyYAML>=5.1.2
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 KB 15.1 MB/s eta 0:00:0000:01
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Collecting h5py>=2.10.0
#   Downloading h5py-3.6.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 105.2 MB/s eta 0:00:0000:01
# Collecting kaldiio>=2.17.0
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.0 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from espnet==202204) (1.8.0)
# Collecting torch_complex
#   Downloading torch_complex-0.4.3-py3-none-any.whl (9.1 kB)
# Collecting nltk>=3.4.5
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 37.0 MB/s eta 0:00:00:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.1 MB/s eta 0:00:00:00:01
# Collecting ctc-segmentation<1.8,>=1.6.6
#   Downloading ctc_segmentation-1.7.1.tar.gz (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 KB 17.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyworld>=0.2.10
#   Downloading pyworld-0.3.0.tar.gz (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 KB 50.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pypinyin<=0.44.0
#   Downloading pypinyin-0.44.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00:00:01
# Collecting espnet_tts_frontend
#   Downloading espnet_tts_frontend-0.0.3-py3-none-any.whl (11 kB)
# Collecting ci_sdr
#   Downloading ci_sdr-0.0.0.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch_wpe
#   Downloading pytorch_wpe-0.0.1-py3-none-any.whl (8.1 kB)
# Collecting matplotlib==3.1.0
#   Downloading matplotlib-3.1.0.tar.gz (37.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 56.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting pillow>=6.1.0
#   Downloading Pillow-9.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 29.8 MB/s eta 0:00:00:00:01
# Collecting editdistance==0.5.2
#   Downloading editdistance-0.5.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting wandb
#   Downloading wandb-0.12.14-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.3 MB/s eta 0:00:00:00:01
# Collecting tensorboard>=1.14
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 114.7 MB/s eta 0:00:0000:01
# Collecting espnet_model_zoo
#   Downloading espnet_model_zoo-0.1.7-py3-none-any.whl (19 kB)
# Collecting gdown
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting resampy
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 KB 5.7 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting pysptk>=0.1.17
#   Downloading pysptk-0.1.20.tar.gz (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.2/410.2 KB 5.0 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Collecting youtube_dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 28.3 MB/s eta 0:00:00:00:01
# Collecting nnmnkwii
#   Downloading nnmnkwii-0.1.1.tar.gz (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.0 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting museval>=0.2.1
#   Downloading museval-0.4.0-py2.py3-none-any.whl (21 kB)
# Collecting pystoi>=0.2.2
#   Downloading pystoi-0.3.3.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mir-eval>=0.6
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 KB 26.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fastdtw
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting nara_wpe>=0.0.5
#   Downloading nara_wpe-0.0.7-py3-none-any.whl (30 kB)
# Collecting sacrebleu>=1.5.1
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 KB 26.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 94.9 MB/s eta 0:00:00
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-3.0.8-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 KB 28.2 MB/s eta 0:00:00
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 KB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from matplotlib==3.1.0->espnet==202204) (1.20.3)
# Collecting Cython
#   Using cached Cython-0.29.28-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Collecting joblib>=0.14
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 KB 53.1 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 KB 11.4 MB/s eta 0:00:00
# Collecting audioread>=2.1.5
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.5/377.5 KB 65.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn>=0.19.1
#   Downloading scikit_learn-1.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 19.1 MB/s eta 0:00:0000:0100:01
# Collecting decorator>=4.0.10
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 18.3 MB/s eta 0:00:00
# Collecting numba>=0.45.1
#   Downloading numba-0.55.1-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 37.5 MB/s eta 0:00:00:00:01
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 KB 13.4 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from mir-eval>=0.6->espnet==202204) (1.16.0)
# Collecting pandas>=1.0.1
#   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 86.6 MB/s eta 0:00:0000:0100:01
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 KB 26.9 MB/s eta 0:00:00
# Collecting musdb>=0.4.0
#   Downloading musdb-0.4.0-py2.py3-none-any.whl (29 kB)
# Collecting jsonschema
#   Downloading jsonschema-4.4.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 KB 23.9 MB/s eta 0:00:00
# Collecting bottleneck
#   Downloading Bottleneck-1.3.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_24_x86_64.whl (331 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.5/331.5 KB 9.1 MB/s eta 0:00:0000:01
# Collecting click
#   Downloading click-8.1.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from nara_wpe>=0.0.5->espnet==202204) (4.64.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.3.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.9/764.9 KB 7.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: colorama in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from sacrebleu>=1.5.1->espnet==202204) (0.4.4)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: cffi>=1.0 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from soundfile>=0.10.2->espnet==202204) (1.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from tensorboard>=1.14->espnet==202204) (2.27.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.5-py2.py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.6/156.6 KB 36.8 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 30.0 MB/s eta 0:00:00
# Collecting absl-py>=0.4
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 KB 4.0 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 52.5 MB/s eta 0:00:00:00:01
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.20.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 84.4 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from tensorboard>=1.14->espnet==202204) (0.37.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 KB 15.4 MB/s eta 0:00:0000:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.1.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 KB 52.9 MB/s eta 0:00:00
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.44.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 27.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from torch>=1.3.0->espnet==202204) (4.1.1)
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 15.4 MB/s eta 0:00:00
# Collecting g2p-en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 43.0 MB/s eta 0:00:00:00:01
# Collecting unidecode>=1.0.22
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 39.2 MB/s eta 0:00:00
# Collecting jaconv
#   Downloading jaconv-0.3.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting inflect>=1.0.0
#   Downloading inflect-5.5.2-py3-none-any.whl (33 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 30.3 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.10-py2.py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 KB 2.0 MB/s eta 0:00:0000:01
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting psutil>=5.0.0
#   Downloading psutil-5.9.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.8/283.8 KB 62.1 MB/s eta 0:00:00
# Collecting GitPython>=1.0.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->espnet==202204) (2.21)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 KB 2.4 MB/s eta 0:00:0000:01
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Collecting stempeg>=0.2.3
#   Downloading stempeg-0.2.3-py3-none-any.whl (963 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 KB 28.9 MB/s eta 0:00:00
# Collecting pyaml
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 23.5 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 79.2 MB/s eta 0:00:00
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->espnet==202204) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->espnet==202204) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->espnet==202204) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->espnet==202204) (3.3)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 KB 47.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting attrs>=17.4.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 15.3 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 KB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->espnet==202204) (1.7.1)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 KB 30.4 MB/s eta 0:00:00
# Collecting ffmpeg-python>=0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Building wheels for collected packages: editdistance, matplotlib, ctc-segmentation, kaldiio, mir-eval, pysptk, pystoi, pyworld, resampy, ci_sdr, fastdtw, gdown, nnmnkwii, audioread, promise, future, jaconv, pathtools, distance
#   Building wheel for editdistance (setup.py) ... done
#   Created wheel for editdistance: filename=editdistance-0.5.2-cp38-cp38-linux_x86_64.whl size=209811 sha256=ad15383c4c43c7eca5794621000ad7f684c0d64f5bf55c66ad8f3bda64903dae
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/56/49/b0/85a377bddd0cde1e3fb5db91a5544938536ab8cd3fb8e05aa8
#   Building wheel for matplotlib (setup.py) ... done
#   Created wheel for matplotlib: filename=matplotlib-3.1.0-cp38-cp38-linux_x86_64.whl size=11301745 sha256=6f692e6fd5d3e939071ceb2be9ddd344e34e600d1d264bf2cb3ea8c425fe62d5
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/e3/bf/f4/e1e2e54d857335e30b6260b39d479cfa222999e85ef9f8b128
#   Building wheel for ctc-segmentation (setup.py) ... done
#   Created wheel for ctc-segmentation: filename=ctc_segmentation-1.7.1-cp38-cp38-linux_x86_64.whl size=129207 sha256=f85ea8ae8c6c86d324aec5ece30907751f71293ec0c1648b2b2a705761e9fbe9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/60/a3/46/329a4b6dec56707be34b93fab0926ae49baf141fc75d99510b
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24471 sha256=e6daa1dcd29a694a80b71edbff0e921ad32ed99586a5784621f65e37e05d12a3
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/49/b3/00/af2103b510836161326bb51e27795407b07fda6969d0ae5967
#   Building wheel for mir-eval (setup.py) ... done
#   Created wheel for mir-eval: filename=mir_eval-0.7-py3-none-any.whl size=100721 sha256=fa1729e7e52390f76d50b720e98cde828c7bb4b5d9ae517fc8baf2cb59f33ffd
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/20/53/83/1d50d15a666140d53eda589db005f7cb53b739c7e54711f51f
#   Building wheel for pysptk (pyproject.toml) ... done
#   Created wheel for pysptk: filename=pysptk-0.1.20-cp38-cp38-linux_x86_64.whl size=1067964 sha256=c0eb76573acd2e8d012ec85fd747230def0b51cf9d3e52c8ec7d14364198c8c5
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/9a/5c/e0/7ba74078f12327da39deb3b86a36cc8d699c312715cab9e9c1
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7793 sha256=fbc8d7471e0060448b5a371e5c6a1a6de90adec37862a9b28f37a1e54f7e612e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/62/35/75/c07f0861a60fb8aacf44fdd5c8c214a224a6c9edb4a4e1402f
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.0-cp38-cp38-linux_x86_64.whl size=716669 sha256=b3c49c17466122fcb5c8400e84e3dc2c11bf74a80e33f941682c02dea5f585ff
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/b7/9d/77/c12111ca99a5a889f7b3a44b55308f7bd230ea9dbaa2a99613
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320732 sha256=64991964acf06462ac417e69ac16635f82e8f0ce3416068433e7462d48d58690
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/6f/d1/5d/f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
#   Building wheel for ci_sdr (setup.py) ... done
#   Created wheel for ci_sdr: filename=ci_sdr-0.0.0-py3-none-any.whl size=14979 sha256=465cde35977890990aa675c84aec2458c3860d04118f4eaf81cd727bfc04c0a9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/3f/3a/b2/d340c4bb4d572394d45f75574e56e9efc0a2de70b4302f6801
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp38-cp38-linux_x86_64.whl size=426543 sha256=2b9d6efc448ea4ec1e32c353f21eda8c20728b216c8ed35a0870045f4c927af9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/e9/ac/30/c962f9d759dd68cb5482727c44441fdfb48040fdbe983857e8
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=70537f24239ba0642b2743febd631a57a362a89a2113de987484fb8746ca8989
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/7b/7b/5d/656f46cd6889e4c93977be9586901d0adc1271b2d876c84c96
#   Building wheel for nnmnkwii (pyproject.toml) ... done
#   Created wheel for nnmnkwii: filename=nnmnkwii-0.1.1-cp38-cp38-linux_x86_64.whl size=3069352 sha256=f292166326f6697b10d51534c470b4d0adc09d3c0abf58601bce6e9452f21d48
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/89/c1/42/d8689b584be5ef5db4f31cb6a97e2edeb5900971fc682f407c
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23153 sha256=a01a3efbd6feb67f241685839e4eedf4b320366ebada91ed300c9a9e77f665e1
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/49/5a/e4/df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21503 sha256=990b73eab4e8ce691f4a7d69f181a701bd7208b97246fc6214038200b61092c1
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/54/aa/01/724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=301eb5b3a279f6e80259a52c59a3eda010d6ded977b0ff4a6cf1fbd948e41542
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
#   Building wheel for jaconv (setup.py) ... done
#   Created wheel for jaconv: filename=jaconv-0.3-py3-none-any.whl size=15564 sha256=eb20fe272c1ab064256f755c415c43e655b8647d906867ac95d5d22df5c1098e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/73/e8/fb/b4ad8117719f79ac73bc05406d1768f845688cdbeed7aad87e
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=76e1b2c006e9beecedbbe293fc59f7449b9f4b2df6e9a0e174ef44d2446e704a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16276 sha256=c32b7b36a88ff96ec403bd8917c881a0b88f1fac700f855f918dc446b52111de
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/fb/a8/64/6edcab63ec51512a87cacf9b3563c711ad6b7b05d61b704493
# Successfully built editdistance matplotlib ctc-segmentation kaldiio mir-eval pysptk pystoi pyworld resampy ci_sdr fastdtw gdown nnmnkwii audioread promise future jaconv pathtools distance
# Installing collected packages: youtube_dl, tensorboard-plugin-wit, tabulate, sentencepiece, pytz, pyasn1, pathtools, morfessor, jamo, jaconv, einops, editdistance, distance, audioread, appdirs, zipp, werkzeug, unidecode, typeguard, torch_complex, threadpoolctl, tensorboard-data-server, soupsieve, smmap, simplejson, shortuuid, setproctitle, sentry-sdk, scipy, rsa, regex, PyYAML, pytorch_wpe, python-dateutil, pyrsistent, pypinyin, pyparsing, pyasn1-modules, psutil, protobuf, promise, portalocker, pillow, oauthlib, llvmlite, kiwisolver, kaldiio, joblib, inflect, humanfriendly, h5py, grpcio, future, filelock, fastdtw, docker-pycreds, decorator, Cython, cycler, configargparse, click, cachetools, bottleneck, attrs, absl-py, soundfile, scikit-learn, sacrebleu, requests-oauthlib, pyworld, pystoi, pysptk, pyaml, pandas, packaging, numba, nltk, mir-eval, matplotlib, importlib-resources, importlib-metadata, google-auth, gitdb, ffmpeg-python, ctc-segmentation, ci_sdr, beautifulsoup4, stempeg, resampy, pooch, nnmnkwii, nara_wpe, markdown, jsonschema, huggingface-hub, google-auth-oauthlib, GitPython, gdown, g2p-en, wandb, tensorboard, musdb, librosa, espnet_tts_frontend, museval, espnet, espnet_model_zoo
#   Running setup.py develop for espnet
# Successfully installed Cython-0.29.28 GitPython-3.1.27 PyYAML-6.0 absl-py-1.0.0 appdirs-1.4.4 attrs-21.4.0 audioread-2.1.9 beautifulsoup4-4.11.1 bottleneck-1.3.4 cachetools-5.0.0 ci_sdr-0.0.0 click-8.1.2 configargparse-1.5.3 ctc-segmentation-1.7.1 cycler-0.11.0 decorator-5.1.1 distance-0.1.3 docker-pycreds-0.4.0 editdistance-0.5.2 einops-0.4.1 espnet-202204 espnet_model_zoo-0.1.7 espnet_tts_frontend-0.0.3 fastdtw-0.3.4 ffmpeg-python-0.2.0 filelock-3.6.0 future-0.18.2 g2p-en-2.1.0 gdown-4.4.0 gitdb-4.0.9 google-auth-2.6.5 google-auth-oauthlib-0.4.6 grpcio-1.44.0 h5py-3.6.0 huggingface-hub-0.5.1 humanfriendly-10.0 importlib-metadata-4.11.3 importlib-resources-5.7.1 inflect-5.5.2 jaconv-0.3 jamo-0.4.1 joblib-1.1.0 jsonschema-4.4.0 kaldiio-2.17.2 kiwisolver-1.4.2 librosa-0.9.1 llvmlite-0.38.0 markdown-3.3.6 matplotlib-3.1.0 mir-eval-0.7 morfessor-2.0.6 musdb-0.4.0 museval-0.4.0 nara_wpe-0.0.7 nltk-3.7 nnmnkwii-0.1.1 numba-0.55.1 oauthlib-3.2.0 packaging-21.3 pandas-1.4.2 pathtools-0.1.2 pillow-9.1.0 pooch-1.6.0 portalocker-2.4.0 promise-2.3 protobuf-3.20.0 psutil-5.9.0 pyaml-21.10.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.8 pypinyin-0.44.0 pyrsistent-0.18.1 pysptk-0.1.20 pystoi-0.3.3 python-dateutil-2.8.2 pytorch_wpe-0.0.1 pytz-2022.1 pyworld-0.3.0 regex-2022.3.15 requests-oauthlib-1.3.1 resampy-0.2.2 rsa-4.8 sacrebleu-2.0.0 scikit-learn-1.0.2 scipy-1.8.0 sentencepiece-0.1.96 sentry-sdk-1.5.10 setproctitle-1.2.3 shortuuid-1.0.8 simplejson-3.17.6 smmap-5.0.0 soundfile-0.10.3.post1 soupsieve-2.3.2.post1 stempeg-0.2.3 tabulate-0.8.9 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 threadpoolctl-3.1.0 torch_complex-0.4.3 typeguard-2.13.3 unidecode-1.3.4 wandb-0.12.14 werkzeug-2.1.1 youtube_dl-2021.12.17 zipp-3.8.0
# touch espnet.done
# . ./activate_python.sh && ./installers/install_fairscale.sh
# <stdin>:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# [INFO] torch_version=1.8.0
# <stdin>:3: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# [WARNING] fairscale requires pytorch>=1.8.1
# touch fairscale.done
# . ./activate_python.sh && ./installers/install_torch_optimizer.sh
# <stdin>:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# [INFO] torch_version=1.8.0
# <stdin>:3: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting torch_optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 KB 17.2 MB/s eta 0:00:00
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch>=1.5.0 in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from torch_optimizer) (1.8.0)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from torch>=1.5.0->torch_optimizer) (4.1.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/espnet/lib/python3.8/site-packages (from torch>=1.5.0->torch_optimizer) (1.20.3)
# Installing collected packages: pytorch-ranger, torch_optimizer
# Successfully installed pytorch-ranger-0.1.1 torch_optimizer-0.3.0
# touch torch_optimizer.done
# . ./activate_python.sh; . ./extra_path.sh; python3 check_install.py
# [x] python=3.8.12 (default, Oct 12 2021, 13:49:34)  [GCC 7.5.0]
#
# Python modules:
# [x] torch=1.8.0
# [x] torch cuda=10.2
# [x] torch cudnn=7605
# [x] torch nccl
# [ ] chainer
# [ ] cupy
# [x] torchaudio=0.8.0a0+a751e1d
# [x] torch_optimizer=0.3.0
# [ ] warpctc_pytorch
# [ ] warprnnt_pytorch
# [ ] chainer_ctc
# [ ] pyopenjtalk
# [ ] tdmelodic_pyopenjtalk
# [ ] kenlm
# [ ] mmseg
# [x] espnet=202204
# [ ] fairseq
# [ ] phonemizer
# [ ] gtn
# [ ] s3prl
# [ ] transformers
# [ ] speechbrain
# [ ] k2
# [ ] longformer
# [ ] nlg-eval
# [ ] datasets
#
# Executables:
# [x] sclite
# [x] sph2pipe
# [ ] PESQ
# [ ] BeamformIt
#
# INFO:
# Use 'installers/install_warp-ctc.sh' to install warpctc_pytorch
# Use 'installers/install_warp-transducer.sh' to install warprnnt_pytorch
# Use 'installers/install_chainer_ctc.sh' to install chainer_ctc
# Use 'installers/install_pyopenjtalk.sh' to install pyopenjtalk
# Use 'installers/install_tdmelodic_pyopenjtalk.sh' to install tdmelodic_pyopenjtalk
# Use 'installers/install_kenlm.sh' to install kenlm
# Use 'installers/install_py3mmseg.sh' to install mmseg
# Use 'installers/install_fairseq.sh' to install fairseq
# Use 'installers/install_phonemizer.sh' to install phonemizer
# Use 'installers/install_gtn.sh' to install gtn
# Use 'installers/install_s3prl.sh' to install s3prl
# Use 'installers/install_transformers.sh' to install transformers
# Use 'installers/install_speechbrain.sh' to install speechbrain
# Use 'installers/install_k2.sh' to install k2
# Use 'installers/install_longformer.sh' to install longformer
# Use 'installers/install_longformer.sh' to install nlg-eval
# Use 'installers/install_longformer.sh' to install datasets
# Use 'installers/install_pesq.sh' to install PESQ
# Use 'installers/install_beamformit.sh' to install BeamformIt

# %%
# %cd /home/ec2-user/anaconda3/envs/espnet/etc/conda
# !rm -rf activate.d
# !rm -rf deactivate.d
# Out:
# /home/ec2-user/anaconda3/envs/espnet/etc/conda

# %% [markdown]
# <h1> Installation finished </h1>
#
# .
# .
# .
# .
# .

# %%
Project_name="German_Male"

# %% [markdown]
# <h1>Create project folder</h1>

# %%
# %cd
# Out:
# /home/ec2-user

# %%
# %%bash -s "$Project_name"
#
# echo $1
#
# /home/ec2-user/SageMaker/espnet/egs2/TEMPLATE/tts1/setup.sh  /home/ec2-user/SageMaker/espnet/egs2/$1/tts1
# cd /home/ec2-user/SageMaker/espnet/egs2/$1/tts1
# pwd
# Out:
# German_Male
# 2022-04-17T17:42:18 (setup.sh:71:main) Created: /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1//home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/tts1/cmd.sh /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1//home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/tts1/conf /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1//home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/tts1/local /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/tts1/tts.sh /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/tts1/path.sh /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/asr1/db.sh /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/asr1/scripts /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../TEMPLATE/asr1/pyscripts /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../../tools/kaldi/egs/wsj/s5/steps /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../../tools/kaldi/egs/wsj/s5/utils /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/../../../tools/kaldi/egs/sre08/v1/sid
# /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1

# %%
# !aws s3 cp 's3://commonvoicesdataset/Text2Speech/GermanMale/wavs.zip' '/home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1'
# Out:
# download: s3://commonvoicesdataset/Text2Speech/GermanMale/wavs.zip to SageMaker/espnet/egs2/German_Male/tts1/wavs.zip

# %%
# %%bash -s "$Project_name"
# unzip -q /home/ec2-user/SageMaker/espnet/egs2/$1/tts1/wavs.zip -d /home/ec2-user/SageMaker/espnet/egs2/$1/tts1/

# %%
# %%bash -s "$Project_name"
# aws s3 cp s3://commonvoicesdataset/Text2Speech/GermanMale/data.zip /home/ec2-user/SageMaker/espnet/egs2/$1/tts1
# Out:
# download: s3://commonvoicesdataset/Text2Speech/GermanMale/data.zip to SageMaker/espnet/egs2/German_Male/tts1/data.zip

# %%
# %%bash -s "$Project_name"
# echo /home/ec2-user/SageMaker/espnet/egs2/$1/tts1/data.zip
# unzip -q /home/ec2-user/SageMaker/espnet/egs2/$1/tts1/data.zip -d /home/ec2-user/SageMaker/espnet/egs2/$1/tts1/
# Out:
# /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1/data.zip

# %%
# %%bash -s "$Project_name"
# rm  /home/ec2-user/SageMaker/espnet/egs2/$1/tts1/wavs.zip

# %%
# %cd /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1
# Out:
# /home/ec2-user/SageMaker/espnet/egs2/German_Male/tts1

# %%
# !./tts.sh \
 --stage 2 \
 --ngpu 1 \
 --train_set train \
 --valid_set valid \
 --test_sets test \
 --stop-stage 2
# Out:
# 2022-04-17T17:44:03 (tts.sh:211:main) ./tts.sh --stage 2 --ngpu 1 --train_set train --valid_set valid --test_sets test --stop-stage 2
# 2022-04-17T17:44:04 (tts.sh:323:main) Stage 2: Format wav.scp: data/ -> dump/raw/
# utils/copy_data_dir.sh: copied data from data/train to dump/raw/org/train
# this program is runnnnnnnnnnnnin
# utils/validate_data_dir.sh: WARNING: you have only one speaker.  This probably a bad idea.
#    Search for the word 'bold' in http://kaldi-asr.org/doc/data_prep.html
#    for more information.
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/org/train
# 2022-04-17T17:44:04 (format_wav_scp.sh:42:main) scripts/audio/format_wav_scp.sh --nj 32 --cmd run.pl --audio-format flac --fs 16000 data/train/wav.scp dump/raw/org/train
# 2022-04-17T17:44:05 (format_wav_scp.sh:110:main) [info]: without segments
# 2022-04-17T17:55:42 (format_wav_scp.sh:142:main) Successfully finished. [elapsed=698s]
# utils/copy_data_dir.sh: copied data from data/valid to dump/raw/org/valid
# this program is runnnnnnnnnnnnin
# utils/validate_data_dir.sh: WARNING: you have only one speaker.  This probably a bad idea.
#    Search for the word 'bold' in http://kaldi-asr.org/doc/data_prep.html
#    for more information.
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/org/valid
# 2022-04-17T17:55:42 (format_wav_scp.sh:42:main) scripts/audio/format_wav_scp.sh --nj 32 --cmd run.pl --audio-format flac --fs 16000 data/valid/wav.scp dump/raw/org/valid
# 2022-04-17T17:55:42 (format_wav_scp.sh:110:main) [info]: without segments
# 2022-04-17T17:57:14 (format_wav_scp.sh:142:main) Successfully finished. [elapsed=92s]
# utils/copy_data_dir.sh: copied data from data/test to dump/raw/test
# this program is runnnnnnnnnnnnin
# utils/validate_data_dir.sh: WARNING: you have only one speaker.  This probably a bad idea.
#    Search for the word 'bold' in http://kaldi-asr.org/doc/data_prep.html
#    for more information.
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/test
# 2022-04-17T17:57:15 (format_wav_scp.sh:42:main) scripts/audio/format_wav_scp.sh --nj 32 --cmd run.pl --audio-format flac --fs 16000 data/test/wav.scp dump/raw/test
# 2022-04-17T17:57:15 (format_wav_scp.sh:110:main) [info]: without segments
# 2022-04-17T17:57:39 (format_wav_scp.sh:142:main) Successfully finished. [elapsed=24s]
# 2022-04-17T17:57:39 (tts.sh:1180:main) Skip the uploading stage
# 2022-04-17T17:57:39 (tts.sh:1232:main) Skip the uploading to HuggingFace stage
# 2022-04-17T17:57:39 (tts.sh:1235:main) Successfully finished. [elapsed=816s]

# %%
# !./tts.sh --stage 3 --stop-stage 3
# Out:
# 2022-04-17T18:05:04 (tts.sh:211:main) ./tts.sh --stage 3 --stop-stage 3
# 2022-04-17T18:05:05 (tts.sh:468:main) Stage 3: Remove long/short data: dump/raw/org -> dump/raw
# utils/copy_data_dir.sh: copied data from dump/raw/org/train to dump/raw/train
# this program is runnnnnnnnnnnnin
# utils/validate_data_dir.sh: WARNING: you have only one speaker.  This probably a bad idea.
#    Search for the word 'bold' in http://kaldi-asr.org/doc/data_prep.html
#    for more information.
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/train
# fix_data_dir.sh: kept all 20179 utterances.
# fix_data_dir.sh: old files are kept in dump/raw/train/.backup
# utils/copy_data_dir.sh: copied data from dump/raw/org/valid to dump/raw/valid
# this program is runnnnnnnnnnnnin
# utils/validate_data_dir.sh: WARNING: you have only one speaker.  This probably a bad idea.
#    Search for the word 'bold' in http://kaldi-asr.org/doc/data_prep.html
#    for more information.
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/valid
# fix_data_dir.sh: kept all 2268 utterances.
# fix_data_dir.sh: old files are kept in dump/raw/valid/.backup
# 2022-04-17T18:05:06 (tts.sh:1180:main) Skip the uploading stage
# 2022-04-17T18:05:06 (tts.sh:1232:main) Skip the uploading to HuggingFace stage
# 2022-04-17T18:05:06 (tts.sh:1235:main) Successfully finished. [elapsed=2s]

# %%
# !./tts.sh --stage 4 --stop-stage 4 --srctexts "data/train/text"
# Out:
# 2022-04-17T18:05:21 (tts.sh:211:main) ./tts.sh --stage 4 --stop-stage 4 --srctexts data/train/text
# 2022-04-17T18:05:21 (tts.sh:523:main) Stage 4: Generate token_list from data/train/text
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# /home/ec2-user/anaconda3/envs/espnet/bin/python3 /home/ec2-user/SageMaker/espnet/espnet2/bin/tokenize_text.py --token_type phn -f 2- --input dump/raw/srctexts --output dump/token_list/phn_tacotron_g2p_en/tokens.txt --non_linguistic_symbols none --cleaner tacotron --g2p g2p_en --write_vocabulary true --add_symbol '<blank>:0' --add_symbol '<unk>:1' --add_symbol '<sos/eos>:-1'
# 2022-04-17 18:08:58,563 (tokenize_text:174) INFO: OOV rate = 0.0 %
# 2022-04-17T18:08:58 (tts.sh:1180:main) Skip the uploading stage
# 2022-04-17T18:08:58 (tts.sh:1232:main) Skip the uploading to HuggingFace stage
# 2022-04-17T18:08:58 (tts.sh:1235:main) Successfully finished. [elapsed=217s]

# %%
# !./tts.sh --stage 5 --stop-stage 5
# Out:
# 2022-04-17T18:12:04 (tts.sh:211:main) ./tts.sh --stage 5 --stop-stage 5
# 2022-04-17T18:12:05 (tts.sh:555:main) Stage 5: TTS collect stats: train_set=dump/raw/train, valid_set=dump/raw/valid
# 2022-04-17T18:12:05 (tts.sh:642:main) Generate 'exp/tts_stats_raw_phn_tacotron_g2p_en/run.sh'. You can resume the process from stage 5 using this script
# 2022-04-17T18:12:05 (tts.sh:646:main) TTS collect_stats started... log: 'exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.*.log'
# /home/ec2-user/anaconda3/envs/espnet/bin/python3 /home/ec2-user/SageMaker/espnet/espnet2/bin/aggregate_stats_dirs.py --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.1 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.2 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.3 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.4 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.5 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.6 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.7 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.8 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.9 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.10 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.11 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.12 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.13 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.14 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.15 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.16 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.17 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.18 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.19 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.20 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.21 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.22 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.23 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.24 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.25 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.26 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.27 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.28 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.29 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.30 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.31 --input_dir exp/tts_stats_raw_phn_tacotron_g2p_en/logdir/stats.32 --output_dir exp/tts_stats_raw_phn_tacotron_g2p_en
# 2022-04-17T18:16:20 (tts.sh:1180:main) Skip the uploading stage
# 2022-04-17T18:16:20 (tts.sh:1232:main) Skip the uploading to HuggingFace stage
# 2022-04-17T18:16:20 (tts.sh:1235:main) Successfully finished. [elapsed=256s]

# %%
# !./tts.sh --stage 6 --stop-stage 6
# Out:
# 2022-04-17T18:17:35 (tts.sh:211:main) ./tts.sh --stage 6 --stop-stage 6
# 2022-04-17T18:17:35 (tts.sh:691:main) Stage 6: TTS Training: train_set=dump/raw/train, valid_set=dump/raw/valid
# 2022-04-17T18:17:35 (tts.sh:871:main) Generate 'exp/tts_train_raw_phn_tacotron_g2p_en/run.sh'. You can resume the process from stage 6 using this script
# 2022-04-17T18:17:35 (tts.sh:876:main) TTS training started... log: 'exp/tts_train_raw_phn_tacotron_g2p_en/train.log'
# 2022-04-17 18:17:36,044 (launch:95) INFO: /home/ec2-user/anaconda3/envs/espnet/bin/python3 /home/ec2-user/SageMaker/espnet/espnet2/bin/launch.py --cmd 'run.pl --name exp/tts_train_raw_phn_tacotron_g2p_en/train.log' --log exp/tts_train_raw_phn_tacotron_g2p_en/train.log --ngpu 1 --num_nodes 1 --init_file_prefix exp/tts_train_raw_phn_tacotron_g2p_en/.dist_init_ --multiprocessing_distributed true -- python3 -m espnet2.bin.tts_train --use_preprocessor true --token_type phn --token_list dump/token_list/phn_tacotron_g2p_en/tokens.txt --non_linguistic_symbols none --cleaner tacotron --g2p g2p_en --normalize global_mvn --resume true --fold_length 150 --fold_length 204800 --output_dir exp/tts_train_raw_phn_tacotron_g2p_en --feats_extract fbank --feats_extract_conf n_fft=1024 --feats_extract_conf hop_length=256 --feats_extract_conf win_length=null --feats_extract_conf fs=16000 --feats_extract_conf fmin=80 --feats_extract_conf fmax=7600 --feats_extract_conf n_mels=80 --train_data_path_and_name_and_type dump/raw/train/text,text,text --train_data_path_and_name_and_type dump/raw/train/wav.scp,speech,sound --train_shape_file exp/tts_stats_raw_phn_tacotron_g2p_en/train/text_shape.phn --train_shape_file exp/tts_stats_raw_phn_tacotron_g2p_en/train/speech_shape --valid_data_path_and_name_and_type dump/raw/valid/text,text,text --valid_data_path_and_name_and_type dump/raw/valid/wav.scp,speech,sound --valid_shape_file exp/tts_stats_raw_phn_tacotron_g2p_en/valid/text_shape.phn --valid_shape_file exp/tts_stats_raw_phn_tacotron_g2p_en/valid/speech_shape --normalize_conf stats_file=exp/tts_stats_raw_phn_tacotron_g2p_en/train/feats_stats.npz
# 2022-04-17 18:17:36,067 (launch:349) INFO: log file: exp/tts_train_raw_phn_tacotron_g2p_en/train.log

# %%
# !./tts.sh --stage 7 --stop-stage 7
# Out:
# 2022-04-18T09:45:13 (tts.sh:211:main) ./tts.sh --stage 7 --stop-stage 7
# 2022-04-18T09:45:13 (tts.sh:933:main) Stage 7: Decoding: training_dir=exp/tts_train_raw_phn_tacotron_g2p_en
# 2022-04-18T09:45:13 (tts.sh:956:main) Generate 'exp/tts_train_raw_phn_tacotron_g2p_en/inference_train.loss.ave/run.sh'. You can resume the process from stage 7 using this script
# 2022-04-18T09:45:13 (tts.sh:1010:main) Decoding started... log: 'exp/tts_train_raw_phn_tacotron_g2p_en/inference_train.loss.ave/test/log/tts_inference.*.log'
# 2022-04-18T09:49:03 (tts.sh:1180:main) Skip the uploading stage
# 2022-04-18T09:49:03 (tts.sh:1232:main) Skip the uploading to HuggingFace stage
# 2022-04-18T09:49:03 (tts.sh:1235:main) Successfully finished. [elapsed=230s]
